# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load The Dataset

# %%
dataset = pd.read_csv(r"C:\Users\Siddhesh\Downloads\Copy of automobile_data.csv")
dataset.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Convert the values "?" to Nan

# %%
dataset = dataset.replace('?', np.nan)

# %%
dataset.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Dropping the Columns Which are not use

# %%
dropped_columns = ['symboling', 'normalized-losses', 'num-of-doors', 'engine-location', 'fuel-system', 'stroke']
dataset = dataset.drop(columns=dropped_columns)

# %%
dataset.head(5)
# Out:
#           make fuel-type aspiration   body-style drive-wheels  wheel-base  \
# 0  alfa-romero       gas        std  convertible          rwd        88.6
# 1  alfa-romero       gas        std  convertible          rwd        88.6
# 2  alfa-romero       gas        std    hatchback          rwd        94.5
# 3         audi       gas        std        sedan          fwd        99.8
# 4         audi       gas        std        sedan          4wd        99.4
#
#    length  width  height  curb-weight engine-type num-of-cylinders  \
# 0   168.8   64.1    48.8         2548        dohc             four
# 1   168.8   64.1    48.8         2548        dohc             four
# 2   171.2   65.5    52.4         2823        ohcv              six
# 3   176.6   66.2    54.3         2337         ohc             four
# 4   176.6   66.4    54.3         2824         ohc             five
#
#    engine-size  bore  compression-ratio horsepower peak-rpm  city-mpg  \
# 0          130  3.47                9.0        111     5000        21
# 1          130  3.47                9.0        111     5000        21
# 2          152  2.68                9.0        154     5000        19
# 3          109  3.19               10.0        102     5500        24
# 4          136  3.19                8.0        115     5500        18
#
#    highway-mpg  price
# 0           27  13495
# 1           27  16500
# 2           26  16500
# 3           30  13950
# 4           22  17450

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               205 non-null    int64
#  1   fuel-type          205 non-null    int64
#  2   aspiration         205 non-null    int64
#  3   body-style         205 non-null    int64
#  4   drive-wheels       205 non-null    int64
#  5   wheel-base         205 non-null    float64
#  6   length             205 non-null    float64
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   curb-weight        205 non-null    int64
#  10  engine-type        205 non-null    int64
#  11  num-of-cylinders   205 non-null    int64
#  12  engine-size        205 non-null    int64
#  13  bore               205 non-null    int64
#  14  compression-ratio  205 non-null    float64
#  15  horsepower         205 non-null    int64
#  16  peak-rpm           205 non-null    int64
#  17  city-mpg           205 non-null    int64
#  18  highway-mpg        205 non-null    int64
#  19  price              205 non-null    int64
# dtypes: float64(5), int64(15)
# memory usage: 32.2 KB

# %% [markdown]
# ## Convert Categorical Data to Numeric Data by using LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
encoded_columns = ['make', 'fuel-type', 'aspiration', 'body-style', 'drive-wheels','engine-type', 'num-of-cylinders', 'bore', 'horsepower', 'peak-rpm', 'price']
for col in encoded_columns:
    dataset[col] = le.fit_transform(dataset[col]).astype('int64')

# %%
dataset.head(5)
# Out:
#    make  fuel-type  aspiration  body-style  drive-wheels  wheel-base  length  \
# 0     0          1           0           0             2        88.6   168.8
# 1     0          1           0           0             2        88.6   168.8
# 2     0          1           0           2             2        94.5   171.2
# 3     1          1           0           3             1        99.8   176.6
# 4     1          1           0           3             0        99.4   176.6
#
#    width  height  curb-weight  engine-type  num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548            0                 2          130
# 1   64.1    48.8         2548            0                 2          130
# 2   65.5    52.4         2823            5                 3          152
# 3   66.2    54.3         2337            3                 2          109
# 4   66.4    54.3         2824            3                 1          136
#
#    bore  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  price
# 0    23                9.0           5        10        21           27     31
# 1    23                9.0           5        10        21           27     50
# 2     1                9.0          20        10        19           26     50
# 3    13               10.0           2        16        24           30     36
# 4    13                8.0           8        16        18           22     61

# %%
dataset.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# body-style           0
# drive-wheels         0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# bore                 0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.describe()
# Out:
#              make   fuel-type  aspiration  body-style  drive-wheels  \
# count  205.000000  205.000000  205.000000  205.000000    205.000000
# mean    12.195122    0.902439    0.180488    2.614634      1.326829
# std      6.274831    0.297446    0.385535    0.859081      0.556171
# min      0.000000    0.000000    0.000000    0.000000      0.000000
# 25%      8.000000    1.000000    0.000000    2.000000      1.000000
# 50%     12.000000    1.000000    0.000000    3.000000      1.000000
# 75%     19.000000    1.000000    0.000000    3.000000      2.000000
# max     21.000000    1.000000    1.000000    4.000000      2.000000
#
#        wheel-base      length       width      height  curb-weight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        engine-type  num-of-cylinders  engine-size        bore  \
# count   205.000000        205.000000   205.000000  205.000000
# mean      3.014634          2.117073   126.907317   18.336585
# std       1.054765          0.795792    41.642693   10.368640
# min       0.000000          0.000000    61.000000    0.000000
# 25%       3.000000          2.000000    97.000000   11.000000
# 50%       3.000000          2.000000   120.000000   16.000000
# 75%       3.000000          2.000000   141.000000   28.000000
# max       6.000000          6.000000   326.000000   38.000000
#
#        compression-ratio  horsepower    peak-rpm    city-mpg  highway-mpg  \
# count         205.000000  205.000000  205.000000  205.000000   205.000000
# mean           10.142537   31.726829   11.604878   25.219512    30.751220
# std             3.972040   18.572949    5.318758    6.542142     6.886443
# min             7.000000    0.000000    0.000000   13.000000    16.000000
# 25%             8.600000   12.000000    8.000000   19.000000    25.000000
# 50%             9.000000   40.000000   12.000000   24.000000    30.000000
# 75%             9.400000   47.000000   16.000000   30.000000    34.000000
# max            23.000000   59.000000   23.000000   49.000000    54.000000
#
#             price
# count  205.000000
# mean    96.648780
# std     54.675007
# min      0.000000
# 25%     50.000000
# 50%     99.000000
# 75%    144.000000
# max    186.000000

# %% [markdown]
# ## Data Visualisation of Selective Columns

# %%
sns.histplot(data=dataset,x="price")
plt.show()

# %%
sns.countplot(data=dataset,x='make')
plt.show()

# %%
sns.boxplot(x='make',y='price',data=dataset)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(dataset.corr(),annot=True, cmap="coolwarm")
plt.show()

# %%
dataset.groupby('make')['price'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='make'>

# %%
sns.barplot(x='drive-wheels',y='price',hue='aspiration',data=dataset)
plt.show()

# %% [markdown]
# ## Training and Testing the Data By using RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Rfr = RandomForestRegressor(n_estimators=100,random_state=42)

# %%
from sklearn.model_selection import train_test_split

# %%
x = dataset.iloc[:,:-1]
y = dataset["price"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test
